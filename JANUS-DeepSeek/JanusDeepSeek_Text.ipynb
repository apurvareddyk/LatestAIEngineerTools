# %%
# !pip install openai==0.28
# Out:
# Collecting openai==0.28
#   Downloading openai-0.28.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.11/dist-packages (from openai==0.28) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from openai==0.28) (4.67.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from openai==0.28) (3.11.12)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->openai==0.28) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->openai==0.28) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->openai==0.28) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->openai==0.28) (2025.1.31)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->openai==0.28) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->openai==0.28) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->openai==0.28) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->openai==0.28) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->openai==0.28) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->openai==0.28) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->openai==0.28) (1.18.3)
# Downloading openai-0.28.0-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 7.1 MB/s eta 0:00:00
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 1.61.1
#     Uninstalling openai-1.61.1:
#       Successfully uninstalled openai-1.61.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# deepseek-r1 0.1.1 requires openai>=1.0.0, but you have openai 0.28.0 which is incompatible.
# Successfully installed openai-0.28.0

# %%
import openai
import time
from IPython.display import clear_output

# Set your API key for DeepSeek R1 (or similar service)
GROQ_API_KEY = "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"
openai.api_key = GROQ_API_KEY

# If your provider requires a custom base URL, set it here:
openai.api_base = "https://api.groq.com/openai/v1"


def deepseek_r1_chat(messages_history):
    """
    Calls the DeepSeek R1 model to continue a conversation.

    Parameters:
      messages_history (list): List of message dictionaries (each with 'role' and 'content').

    Returns:
      str: The assistant's reply or an error message.
    """
    try:
        response = openai.ChatCompletion.create(
            model="deepseek-r1-distill-llama-70b",
            messages=messages_history,
            temperature=0.7,
            max_tokens=4096,
            top_p=0.95
        )
        # Return the content of the assistant's message
        return response["choices"][0]["message"]["content"]
    except Exception as err:
        return f"Error during chat: {err}"


def start_interactive_chat():
    """
    Initiates an interactive chat loop with the DeepSeek R1 model.
    Type 'quit' to exit and 'clear' to reset the conversation.
    """
    conversation_history = []
    print("Start chatting with DeepSeek R1! (Type 'quit' to exit, 'clear' to reset the conversation.)")
    while True:
        user_message = input("\nYou: ")
        if user_message.lower().strip() == "quit":
            print("Exiting chat. Goodbye!")
            break
        if user_message.lower().strip() == "clear":
            conversation_history = []
            clear_output(wait=True)
            print("Chat history cleared. Start a new conversation!")
            continue

        # Add the user's message to the conversation history
        conversation_history.append({"role": "user", "content": user_message})

        # Get the response from DeepSeek R1
        reply = deepseek_r1_chat(conversation_history)
        conversation_history.append({"role": "assistant", "content": reply})
        print("\nDeepSeek R1:", reply)

        # Short pause to help avoid rate limits
        time.sleep(0.5)

# Uncomment the line below to start the interactive chat.
start_interactive_chat()
# Out:
# Start chatting with DeepSeek R1! (Type 'quit' to exit, 'clear' to reset the conversation.)
#
# You: hi
#
# DeepSeek R1: <think>
#
# </think>
#
# Hello! How can I assist you today? 😊
#
# You: how to excel in data science field
#
# DeepSeek R1: <think>
# Alright, the user is asking how to excel in the data science field. They might be someone new to this area looking for guidance.
#
# I should start by breaking down the key skills they need. Programming is essential, so Python and R are musts. Also, SQL is crucial for data handling.
#
# Next, data analysis and machine learning are core areas. They should understand statistics and different algorithms.
#
# Data visualization is another important part, so tools like Tableau or Power BI could be helpful.
#
# They need to learn about big data technologies since handling large datasets is common in this field.
#
# A strong foundation in math, especially linear algebra and calculus, will really help them grasp the concepts deeply.
#
# Gaining practical experience is vital. Working on projects and participating in Kaggle competitions can provide real-world practice.
#
# Staying updated with industry trends and continuous learning are also key because the field evolves rapidly.
#
# Soft skills like communication are important to present their findings effectively.
#
# Networking and building a portfolio will help them stand out when looking for opportunities.
#
# Lastly, considering advanced studies or certifications can further their career.
#
# Putting all these together should give them a clear roadmap to excel in data science.
# </think>
#
# To excel in the data science field, you need to build a strong foundation in technical skills, stay updated with industry trends, and continuously work on improving your problem-solving and analytical abilities. Here are some key steps to help you excel:
#
# ---
#
# ### 1. **Learn Core Skills**
#    - **Programming**:
#      - Python and R are the most commonly used languages in data science. Python is particularly popular due to its extensive libraries (e.g., NumPy, pandas, and scikit-learn).
#      - SQL is essential for data manipulation and querying databases.
#    - **Data Analysis and Machine Learning**:
#      - Understand statistics (descriptive, inferential, and probabilistic concepts).
#      - Learn machine learning algorithms (supervised, unsupervised, and reinforcement learning).
#      - Familiarize yourself with libraries like scikit-learn, TensorFlow, and PyTorch.
#    - **Data Visualization**:
#      - Learn tools like Tableau, Power BI, or Python libraries (Matplotlib, Seaborn, Plotly) to visualize data effectively.
#    - **Big Data Technologies**:
#      - Learn Hadoop, Spark, and cloud platforms (AWS, Azure, Google Cloud) for handling large-scale data.
#
# ---
#
# ### 2. **Work on Practical Projects**
#    - **Real-World Projects**: Apply your skills to real-world datasets. Start with simple projects (e.g., predicting house prices, analyzing customer data) and gradually move to more complex ones.
#    - **Kaggle Competitions**: Participate in Kaggle competitions to practice and learn from others in the community.
#    - **Open Source Contributions**: Contribute to open-source data science projects to gain experience and visibility.
#
# ---
#
# ### 3. **Build a Strong Foundation in Mathematics**
#    - **Linear Algebra**: Understand concepts like vectors, matrices, and eigenvectors, as they are critical for machine learning.
#    - **Calculus**: Learn differentiation and integration, which are essential for optimization in machine learning.
#    - **Probability and Statistics**: Understand distributions, hypothesis testing, and confidence intervals.
#
# ---
#
# ### 4. **Stay Updated with Industry Trends**
#    - Follow blogs, podcasts, and YouTube channels related to data science.
#    - Attend webinars, meetups, and conferences (e.g., NeurIPS, ICML, Strata Data Conference).
#    - Explore emerging areas like deep learning, natural language processing (NLP), and reinforcement learning.
#
# ---
#
# ### 5. **Develop Soft Skills**
#    - **Communication**: Learn to present complex data insights in a simple, actionable way.
#    - **Problem-Solving**: Develop a mindset to approach problems systematically and think critically.
#    - **Collaboration**: Work in teams, as data science is often a collaborative effort involving data engineers, product managers, and domain experts.
#
# ---
#
# ### 6. **Network and Build a Portfolio**
#    - **LinkedIn Profile**: Showcase your skills, projects, and certifications.
#    - **GitHub/Portfolio Website**: Share your code and projects publicly to demonstrate your capabilities.
#    - **Networking**: Join data science communities (e.g., Kaggle, Reddit, LinkedIn groups) and engage with professionals in the field.
#
# ---
#
# ### 7. **Pursue Advanced Education or Certifications**
#    - Consider certifications like:
#      - **Google Data Analytics Certification**
#      - **Microsoft AI Fundamentals Certification**
#      - **Certified Data Scientist (Data Science Council of America)**
#    - If you want to specialize further, consider a master’s degree in data science or a related field.
#
# ---
#
# ### 8. **Read Books and Resources**
#    - **Books**:
#      - "Hands-On Machine Learning with Scikit-Learn, Keras, and TensorFlow" by Aurélien Géron
#      - "Python Data Science Handbook" by Jake VanderPlas
#      - "Interpretable Machine Learning" by Christoph Molnar
#    - **Blogs**:
#      - Towards Data Science (Medium)
#      - KDnuggets
#      - Data Science Times
#
# ---
#
# ### 9. **Practice and Experiment**
#    - Data science is a hands-on field. The more you practice, the better you become. Use platforms like Jupyter Notebooks or Google Colab to experiment with different algorithms and techniques.
#
# ---
#
# ### 10. **Focus on Domain Knowledge**
#    - Specialize in a specific domain (e.g., healthcare, finance, retail) to combine your data science skills with industry-specific knowledge. This makes you more valuable to employers.
#
# ---
#
# ### 11. **Participate in Hackathons and Competitions**
#    - Platforms like HackerRank, LeetCode, and Kaggle host regular competitions that can help you improve your coding and problem-solving skills.
#
# ---
#
# ### 12. **Continuous Learning**
#    - The data science field evolves rapidly. Dedicate time to learning new tools, algorithms, and methodologies.
#
# ---
#
# By following these steps, you can build a strong foundation and excel in the data science field. Remember, consistency and practice are key!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-de8491a57ada> in <cell line: 0>()
#      65
#      66 # Uncomment the line below to start the interactive chat.
# ---> 67 start_interactive_chat()
#
# <ipython-input-1-de8491a57ada> in start_interactive_chat()
#      43     print("Start chatting with DeepSeek R1! (Type 'quit' to exit, 'clear' to reset the conversation.)")
#      44     while True:
# ---> 45         user_message = input("\nYou: ")
#      46         if user_message.lower().strip() == "quit":
#      47             print("Exiting chat. Goodbye!")
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
